# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
import seaborn as sns
# %matplotlib inline
pd.set_option('display.max_columns', None)

# %%
df_c = pd.read_csv('./calendar.csv')

# %%
df_l = pd.read_csv('./listings.csv')

# %%
df_r = pd.read_csv('./reviews.csv')

# %%
df_l.sample(2)
# Out:
#            id                           listing_url       scrape_id  \
# 242   6315614  https://www.airbnb.com/rooms/6315614  20160104002432
# 1276  8811781  https://www.airbnb.com/rooms/8811781  20160104002432
#
#      last_scraped                               name  \
# 242    2016-01-04                 Queen Anne Comfort
# 1276   2016-01-04  Beautiful Belltown Apartment! CT3
#
#                                                 summary  \
# 242   Like so many other places in Seattle we have a...
# 1276  This spacious 3 bed, 2 bath vacation rental sl...
#
#                                                   space  \
# 242                                                 NaN
# 1276  Experience Seattle from our spectacular Centen...
#
#                                             description experiences_offered  \
# 242   Like so many other places in Seattle we have a...                none
# 1276  This spacious 3 bed, 2 bath vacation rental sl...                none
#
#                                   neighborhood_overview  \
# 242                                                 NaN
# 1276  The Centennial Tower is located right on 4th A...
#
#                                                   notes  \
# 242                                                 NaN
# 1276  All of our rentals are fully licensed and regu...
#
#                                                 transit  \
# 242                                                 NaN
# 1276  Convenient public transportation. The location...
#
#                                           thumbnail_url  \
# 242   https://a2.muscache.com/ac/pictures/78918612/8...
# 1276  https://a2.muscache.com/ac/pictures/3e263167-d...
#
#                                              medium_url  \
# 242   https://a2.muscache.com/im/pictures/78918612/8...
# 1276  https://a2.muscache.com/im/pictures/3e263167-d...
#
#                                             picture_url  \
# 242   https://a2.muscache.com/ac/pictures/78918612/8...
# 1276  https://a2.muscache.com/ac/pictures/3e263167-d...
#
#                                          xl_picture_url   host_id  \
# 242   https://a2.muscache.com/ac/pictures/78918612/8...  27215994
# 1276  https://a2.muscache.com/ac/pictures/3e263167-d...   4962900
#
#                                         host_url host_name  host_since  \
# 242   https://www.airbnb.com/users/show/27215994  Jonathan  2015-02-04
# 1276   https://www.airbnb.com/users/show/4962900    Jordan  2013-02-04
#
#                            host_location  \
# 242   Seattle, Washington, United States
# 1276  Spokane, Washington, United States
#
#                                              host_about  host_response_time  \
# 242                                                 NaN  within a few hours
# 1276  Stay Alfred was created based on the idea of o...      within an hour
#
#      host_response_rate host_acceptance_rate host_is_superhost  \
# 242                100%                  NaN                 f
# 1276                99%                 100%                 f
#
#                                      host_thumbnail_url  \
# 242   https://a2.muscache.com/ac/pictures/4643f49c-3...
# 1276  https://a1.muscache.com/ac/users/4962900/profi...
#
#                                        host_picture_url  \
# 242   https://a2.muscache.com/ac/pictures/4643f49c-3...
# 1276  https://a1.muscache.com/ac/users/4962900/profi...
#
#              host_neighbourhood  host_listings_count  \
# 242                  Queen Anne                  1.0
# 1276  Central Business District                169.0
#
#       host_total_listings_count  \
# 242                         1.0
# 1276                      169.0
#
#                                      host_verifications host_has_profile_pic  \
# 242              ['email', 'phone', 'reviews', 'jumio']                    t
# 1276  ['email', 'phone', 'linkedin', 'reviews', 'jum...                    t
#
#      host_identity_verified  \
# 242                       t
# 1276                      t
#
#                                                  street neighbourhood  \
# 242   Taylor Avenue North, Seattle, WA 98109, United...    Queen Anne
# 1276       4th Avenue, Seattle, WA 98121, United States      Belltown
#
#      neighbourhood_cleansed neighbourhood_group_cleansed     city state  \
# 242         East Queen Anne                   Queen Anne  Seattle    WA
# 1276               Belltown                     Downtown  Seattle    WA
#
#      zipcode   market smart_location country_code        country   latitude  \
# 242    98109  Seattle    Seattle, WA           US  United States  47.629388
# 1276   98121  Seattle    Seattle, WA           US  United States  47.617580
#
#        longitude is_location_exact property_type        room_type  \
# 242  -122.345925                 t     Apartment  Entire home/apt
# 1276 -122.345989                 t     Apartment  Entire home/apt
#
#       accommodates  bathrooms  bedrooms  beds  bed_type  \
# 242              4        1.0       1.0   2.0  Real Bed
# 1276             7        2.0       3.0   4.0  Real Bed
#
#                                               amenities  square_feet    price  \
# 242   {TV,Internet,"Wireless Internet","Pets Allowed...          NaN  $109.00
# 1276  {TV,"Cable TV",Internet,"Wireless Internet",Po...          NaN  $127.00
#
#      weekly_price monthly_price security_deposit cleaning_fee  \
# 242           NaN           NaN              NaN          NaN
# 1276          NaN           NaN              NaN      $109.00
#
#       guests_included extra_people  minimum_nights  maximum_nights  \
# 242                 1        $0.00               1            1125
# 1276                1        $0.00               2            1125
#
#      calendar_updated has_availability  availability_30  availability_60  \
# 242      8 months ago                t                0                0
# 1276      2 weeks ago                t               20               50
#
#       availability_90  availability_365 calendar_last_scraped  \
# 242                 0               216            2016-01-04
# 1276               80               350            2016-01-04
#
#       number_of_reviews first_review last_review  review_scores_rating  \
# 242                   0          NaN         NaN                   NaN
# 1276                  3   2015-11-20  2015-12-20                 100.0
#
#       review_scores_accuracy  review_scores_cleanliness  \
# 242                      NaN                        NaN
# 1276                    10.0                       10.0
#
#       review_scores_checkin  review_scores_communication  \
# 242                     NaN                          NaN
# 1276                    9.0                         10.0
#
#       review_scores_location  review_scores_value requires_license  license  \
# 242                      NaN                  NaN                f      NaN
# 1276                    10.0                 10.0                f      NaN
#
#      jurisdiction_names instant_bookable cancellation_policy  \
# 242          WASHINGTON                f            flexible
# 1276         WASHINGTON                f              strict
#
#      require_guest_profile_picture require_guest_phone_verification  \
# 242                              f                                f
# 1276                             f                                f
#
#       calculated_host_listings_count  reviews_per_month
# 242                                1                NaN
# 1276                               1               1.96

# %%
df_l.select_dtypes(include=['integer','float']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              3818 non-null   int64
#  1   scrape_id                       3818 non-null   int64
#  2   host_id                         3818 non-null   int64
#  3   host_listings_count             3816 non-null   float64
#  4   host_total_listings_count       3816 non-null   float64
#  5   latitude                        3818 non-null   float64
#  6   longitude                       3818 non-null   float64
#  7   accommodates                    3818 non-null   int64
#  8   bathrooms                       3802 non-null   float64
#  9   bedrooms                        3812 non-null   float64
#  10  beds                            3817 non-null   float64
#  11  square_feet                     97 non-null     float64
#  12  guests_included                 3818 non-null   int64
#  13  minimum_nights                  3818 non-null   int64
#  14  maximum_nights                  3818 non-null   int64
#  15  availability_30                 3818 non-null   int64
#  16  availability_60                 3818 non-null   int64
#  17  availability_90                 3818 non-null   int64
#  18  availability_365                3818 non-null   int64
#  19  number_of_reviews               3818 non-null   int64
#  20  review_scores_rating            3171 non-null   float64
#  21  review_scores_accuracy          3160 non-null   float64
#  22  review_scores_cleanliness       3165 non-null   float64
#  23  review_scores_checkin           3160 non-null   float64
#  24  review_scores_communication     3167 non-null   float64
#  25  review_scores_location          3163 non-null   float64
#  26  review_scores_value             3162 non-null   float64
#  27  license                         0 non-null      float64
#  28  calculated_host_listings_count  3818 non-null   int64
#  29  reviews_per_month               3191 non-null   float64
# dtypes: float64(17), int64(13)
# memory usage: 895.0 KB

# %%
df_l.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 92 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                3818 non-null   int64
#  1   listing_url                       3818 non-null   object
#  2   scrape_id                         3818 non-null   int64
#  3   last_scraped                      3818 non-null   object
#  4   name                              3818 non-null   object
#  5   summary                           3641 non-null   object
#  6   space                             3249 non-null   object
#  7   description                       3818 non-null   object
#  8   experiences_offered               3818 non-null   object
#  9   neighborhood_overview             2786 non-null   object
#  10  notes                             2212 non-null   object
#  11  transit                           2884 non-null   object
#  12  thumbnail_url                     3498 non-null   object
#  13  medium_url                        3498 non-null   object
#  14  picture_url                       3818 non-null   object
#  15  xl_picture_url                    3498 non-null   object
#  16  host_id                           3818 non-null   int64
#  17  host_url                          3818 non-null   object
#  18  host_name                         3816 non-null   object
#  19  host_since                        3816 non-null   object
#  20  host_location                     3810 non-null   object
#  21  host_about                        2959 non-null   object
#  22  host_response_time                3295 non-null   object
#  23  host_response_rate                3295 non-null   object
#  24  host_acceptance_rate              3045 non-null   object
#  25  host_is_superhost                 3816 non-null   object
#  26  host_thumbnail_url                3816 non-null   object
#  27  host_picture_url                  3816 non-null   object
#  28  host_neighbourhood                3518 non-null   object
#  29  host_listings_count               3816 non-null   float64
#  30  host_total_listings_count         3816 non-null   float64
#  31  host_verifications                3818 non-null   object
#  32  host_has_profile_pic              3816 non-null   object
#  33  host_identity_verified            3816 non-null   object
#  34  street                            3818 non-null   object
#  35  neighbourhood                     3402 non-null   object
#  36  neighbourhood_cleansed            3818 non-null   object
#  37  neighbourhood_group_cleansed      3818 non-null   object
#  38  city                              3818 non-null   object
#  39  state                             3818 non-null   object
#  40  zipcode                           3811 non-null   object
#  41  market                            3818 non-null   object
#  42  smart_location                    3818 non-null   object
#  43  country_code                      3818 non-null   object
#  44  country                           3818 non-null   object
#  45  latitude                          3818 non-null   float64
#  46  longitude                         3818 non-null   float64
#  47  is_location_exact                 3818 non-null   object
#  48  property_type                     3817 non-null   object
#  49  room_type                         3818 non-null   object
#  50  accommodates                      3818 non-null   int64
#  51  bathrooms                         3802 non-null   float64
#  52  bedrooms                          3812 non-null   float64
#  53  beds                              3817 non-null   float64
#  54  bed_type                          3818 non-null   object
#  55  amenities                         3818 non-null   object
#  56  square_feet                       97 non-null     float64
#  57  price                             3818 non-null   object
#  58  weekly_price                      2009 non-null   object
#  59  monthly_price                     1517 non-null   object
#  60  security_deposit                  1866 non-null   object
#  61  cleaning_fee                      2788 non-null   object
#  62  guests_included                   3818 non-null   int64
#  63  extra_people                      3818 non-null   object
#  64  minimum_nights                    3818 non-null   int64
#  65  maximum_nights                    3818 non-null   int64
#  66  calendar_updated                  3818 non-null   object
#  67  has_availability                  3818 non-null   object
#  68  availability_30                   3818 non-null   int64
#  69  availability_60                   3818 non-null   int64
#  70  availability_90                   3818 non-null   int64
#  71  availability_365                  3818 non-null   int64
#  72  calendar_last_scraped             3818 non-null   object
#  73  number_of_reviews                 3818 non-null   int64
#  74  first_review                      3191 non-null   object
#  75  last_review                       3191 non-null   object
#  76  review_scores_rating              3171 non-null   float64
#  77  review_scores_accuracy            3160 non-null   float64
#  78  review_scores_cleanliness         3165 non-null   float64
#  79  review_scores_checkin             3160 non-null   float64
#  80  review_scores_communication       3167 non-null   float64
#  81  review_scores_location            3163 non-null   float64
#  82  review_scores_value               3162 non-null   float64
#  83  requires_license                  3818 non-null   object
#  84  license                           0 non-null      float64
#  85  jurisdiction_names                3818 non-null   object
#  86  instant_bookable                  3818 non-null   object
#  87  cancellation_policy               3818 non-null   object
#  88  require_guest_profile_picture     3818 non-null   object
#  89  require_guest_phone_verification  3818 non-null   object
#  90  calculated_host_listings_count    3818 non-null   int64
#  91  reviews_per_month                 3191 non-null   float64
# dtypes: float64(17), int64(13), object(62)
# memory usage: 2.7+ MB

# %%
df_l.hist( figsize=(15,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000026EAB931888>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026EA7846388>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026EA7E4AB08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026EA720B4C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026EA36E99C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000026EA373C788>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026EA3742F08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026EAC6F8E08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026E9A890548>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026EA9811708>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000026EA75DBCC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026EA36A8D48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026EA97D6608>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026EA7503F88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026EA37480C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000026EA74FF1C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026EA7E76288>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026EAC82B388>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026EA379A488>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026EA90B55C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000026EA906D708>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026EA9021788>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026EA8F95888>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026EA8F529C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026EA7F45AC8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000026EA7F0EBC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026EA7ECC588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026EA90E87C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026EA68CEE88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026EA97B7FC8>]],
#       dtype=object)
