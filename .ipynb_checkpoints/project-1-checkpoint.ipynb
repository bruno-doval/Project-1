# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
import seaborn as sns
# %matplotlib inline
pd.set_option('display.max_columns', None)

# %% [markdown]
# First we will read the data avaliable:

# %%
cal = pd.read_csv('./calendar.csv')
listing = pd.read_csv('./listings.csv')
review = pd.read_csv('./reviews.csv')

# %% [markdown]
# Next we will clead the data defining some functions to:<br>
#     - Trasnform the price value from string to float<br>
#     - Transform the date columns to a Pandas datetime columns<br>
#     - Finally set the columns that have True and False values as 't/f' to boolean Values os True and False

# %%
def price_to_numeric(price_str):
    try:
        return float(price_str[1:])
    except:
        return None

# %%
def percentage_to_numeric(pct_str):
    try:
        return float(pct_str[:-1])/100
    except:
        return None

# %%
def clean_calendar_df(df):
  # Cleans calendar.csv Pandas DataFrame
    
    df.date=pd.to_datetime(df.date)
    df.price=df.price.apply(lambda x: price_to_numeric(x))
    df.available=df.available.apply(lambda x: True if x=='t' else False)
    
    return df

# %%
def clean_listing_df(df,date_columns,t_f_columns,percent_columns,price_columns,age_columns):
  
   # Cleans listing.csv Pandas DataFrame

    for date_col in date_columns:
        df[date_col]=pd.to_datetime(df[date_col])
    
    for t_f_col in t_f_columns:
        df[t_f_col]=df[t_f_col].apply(lambda x: True if x=='t' else False)
        
    for percent_col in percent_columns:
        df[percent_col]=df[percent_col].apply(lambda x: percentage_to_numeric(x))
        
    for price_col in price_columns:
        df[price_col]=df[price_col].apply(lambda x: price_to_numeric(x))
        
    for age_col in age_columns:
        df[age_col+'_age']=(listing.last_scraped-listing[age_col]).dt.days

    df=df.dropna(how='all',axis=1)    
    return df

# %%
cal=clean_calendar_df(cal)

# %%
date_columns_listing=['last_scraped','host_since','calendar_last_scraped','first_review','last_review']

true_false_listing_columns=['host_is_superhost','host_has_profile_pic','host_identity_verified',
                            'is_location_exact','has_availability','requires_license','instant_bookable',
                            'require_guest_profile_picture','require_guest_phone_verification']

percentage_columns_listing=['host_response_rate','host_acceptance_rate']

price_columns_listing=['price','weekly_price','monthly_price','security_deposit','cleaning_fee','extra_people']

age_columns_listing=['host_since','first_review','last_review']


listing=clean_listing_df(listing,
                         date_columns_listing,
                         true_false_listing_columns,
                         percentage_columns_listing,
                         price_columns_listing,
                        age_columns_listing)

# %% [markdown]
# Examining the listing DataFrame:

# %%
listing.head(3)
# Out:
#         id                           listing_url       scrape_id last_scraped  \
# 0   241032   https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 1   953595   https://www.airbnb.com/rooms/953595  20160104002432   2016-01-04
# 2  3308979  https://www.airbnb.com/rooms/3308979  20160104002432   2016-01-04
#
#                                   name  \
# 0         Stylish Queen Anne Apartment
# 1   Bright & Airy Queen Anne Apartment
# 2  New Modern House-Amazing water view
#
#                                              summary  \
# 0                                                NaN
# 1  Chemically sensitive? We've removed the irrita...
# 2  New modern house built in 2013.  Spectacular s...
#
#                                                space  \
# 0  Make your self at home in this charming one-be...
# 1  Beautiful, hypoallergenic apartment in an extr...
# 2  Our house is modern, light and fresh with a wa...
#
#                                          description experiences_offered  \
# 0  Make your self at home in this charming one-be...                none
# 1  Chemically sensitive? We've removed the irrita...                none
# 2  New modern house built in 2013.  Spectacular s...                none
#
#                                neighborhood_overview  \
# 0                                                NaN
# 1  Queen Anne is a wonderful, truly functional vi...
# 2  Upper Queen Anne is a charming neighborhood fu...
#
#                                                notes  \
# 0                                                NaN
# 1  What's up with the free pillows?  Our home was...
# 2  Our house is located just 5 short blocks to To...
#
#                                              transit  \
# 0                                                NaN
# 1  Convenient bus stops are just down the block, ...
# 2  A bus stop is just 2 blocks away.   Easy bus a...
#
#                                        thumbnail_url  \
# 0                                                NaN
# 1  https://a0.muscache.com/ac/pictures/14409893/f...
# 2                                                NaN
#
#                                           medium_url  \
# 0                                                NaN
# 1  https://a0.muscache.com/im/pictures/14409893/f...
# 2                                                NaN
#
#                                          picture_url  \
# 0  https://a1.muscache.com/ac/pictures/67560560/c...
# 1  https://a0.muscache.com/ac/pictures/14409893/f...
# 2  https://a2.muscache.com/ac/pictures/b4324e0f-a...
#
#                                       xl_picture_url   host_id  \
# 0                                                NaN    956883
# 1  https://a0.muscache.com/ac/pictures/14409893/f...   5177328
# 2                                                NaN  16708587
#
#                                      host_url host_name host_since  \
# 0    https://www.airbnb.com/users/show/956883     Maija 2011-08-11
# 1   https://www.airbnb.com/users/show/5177328    Andrea 2013-02-21
# 2  https://www.airbnb.com/users/show/16708587      Jill 2014-06-12
#
#                         host_location  \
# 0  Seattle, Washington, United States
# 1  Seattle, Washington, United States
# 2  Seattle, Washington, United States
#
#                                           host_about  host_response_time  \
# 0  I am an artist, interior designer, and run a s...  within a few hours
# 1  Living east coast/left coast/overseas.  Time i...      within an hour
# 2  i love living in Seattle.  i grew up in the mi...  within a few hours
#
#    host_response_rate  host_acceptance_rate  host_is_superhost  \
# 0                0.96                   1.0              False
# 1                0.98                   1.0               True
# 2                0.67                   1.0              False
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/ac/users/956883/profil...
# 1  https://a0.muscache.com/ac/users/5177328/profi...
# 2  https://a1.muscache.com/ac/users/16708587/prof...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/ac/users/956883/profil...         Queen Anne
# 1  https://a0.muscache.com/ac/users/5177328/profi...         Queen Anne
# 2  https://a1.muscache.com/ac/users/16708587/prof...         Queen Anne
#
#    host_listings_count  host_total_listings_count  \
# 0                  3.0                        3.0
# 1                  6.0                        6.0
# 2                  2.0                        2.0
#
#                                   host_verifications  host_has_profile_pic  \
# 0               ['email', 'phone', 'reviews', 'kba']                  True
# 1  ['email', 'phone', 'facebook', 'linkedin', 're...                  True
# 2   ['email', 'phone', 'google', 'reviews', 'jumio']                  True
#
#    host_identity_verified                                             street  \
# 0                    True      Gilman Dr W, Seattle, WA 98119, United States
# 1                    True  7th Avenue West, Seattle, WA 98119, United States
# 2                    True  West Lee Street, Seattle, WA 98119, United States
#
#   neighbourhood neighbourhood_cleansed neighbourhood_group_cleansed     city  \
# 0    Queen Anne        West Queen Anne                   Queen Anne  Seattle
# 1    Queen Anne        West Queen Anne                   Queen Anne  Seattle
# 2    Queen Anne        West Queen Anne                   Queen Anne  Seattle
#
#   state zipcode   market smart_location country_code        country  \
# 0    WA   98119  Seattle    Seattle, WA           US  United States
# 1    WA   98119  Seattle    Seattle, WA           US  United States
# 2    WA   98119  Seattle    Seattle, WA           US  United States
#
#     latitude   longitude  is_location_exact property_type        room_type  \
# 0  47.636289 -122.371025               True     Apartment  Entire home/apt
# 1  47.639123 -122.365666               True     Apartment  Entire home/apt
# 2  47.629724 -122.369483               True         House  Entire home/apt
#
#    accommodates  bathrooms  bedrooms  beds  bed_type  \
# 0             4        1.0       1.0   1.0  Real Bed
# 1             4        1.0       1.0   1.0  Real Bed
# 2            11        4.5       5.0   7.0  Real Bed
#
#                                            amenities  square_feet  price  \
# 0  {TV,"Cable TV",Internet,"Wireless Internet","A...          NaN   85.0
# 1  {TV,Internet,"Wireless Internet",Kitchen,"Free...          NaN  150.0
# 2  {TV,"Cable TV",Internet,"Wireless Internet","A...          NaN  975.0
#
#    weekly_price  monthly_price  security_deposit  cleaning_fee  \
# 0           NaN            NaN               NaN           NaN
# 1           NaN            NaN             100.0          40.0
# 2           NaN            NaN               NaN         300.0
#
#    guests_included  extra_people  minimum_nights  maximum_nights  \
# 0                2           5.0               1             365
# 1                1           0.0               2              90
# 2               10          25.0               4              30
#
#   calendar_updated  has_availability  availability_30  availability_60  \
# 0      4 weeks ago              True               14               41
# 1            today              True               13               13
# 2      5 weeks ago              True                1                6
#
#    availability_90  availability_365 calendar_last_scraped  number_of_reviews  \
# 0               71               346            2016-01-04                207
# 1               16               291            2016-01-04                 43
# 2               17               220            2016-01-04                 20
#
#   first_review last_review  review_scores_rating  review_scores_accuracy  \
# 0   2011-11-01  2016-01-02                  95.0                    10.0
# 1   2013-08-19  2015-12-29                  96.0                    10.0
# 2   2014-07-30  2015-09-03                  97.0                    10.0
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                       10.0                   10.0
# 1                       10.0                   10.0
# 2                       10.0                   10.0
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         10.0                     9.0                 10.0
# 1                         10.0                    10.0                 10.0
# 2                         10.0                    10.0                 10.0
#
#    requires_license jurisdiction_names  instant_bookable cancellation_policy  \
# 0             False         WASHINGTON             False            moderate
# 1             False         WASHINGTON             False              strict
# 2             False         WASHINGTON             False              strict
#
#    require_guest_profile_picture  require_guest_phone_verification  \
# 0                          False                             False
# 1                           True                              True
# 2                          False                             False
#
#    calculated_host_listings_count  reviews_per_month  host_since_age  \
# 0                               2               4.07          1607.0
# 1                               6               1.48          1047.0
# 2                               2               1.15           571.0
#
#    first_review_age  last_review_age
# 0            1525.0              2.0
# 1             868.0              6.0
# 2             523.0            123.0

# %%
listing.describe()
# Out:
#                  id     scrape_id       host_id  host_response_rate  \
# count  3.818000e+03  3.818000e+03  3.818000e+03         3295.000000
# mean   5.550111e+06  2.016010e+13  1.578556e+07            0.948868
# std    2.962660e+06  0.000000e+00  1.458382e+07            0.118667
# min    3.335000e+03  2.016010e+13  4.193000e+03            0.170000
# 25%    3.258256e+06  2.016010e+13  3.275204e+06            0.980000
# 50%    6.118244e+06  2.016010e+13  1.055814e+07            1.000000
# 75%    8.035127e+06  2.016010e+13  2.590309e+07            1.000000
# max    1.034016e+07  2.016010e+13  5.320861e+07            1.000000
#
#        host_acceptance_rate  host_listings_count  host_total_listings_count  \
# count           3045.000000          3816.000000                3816.000000
# mean               0.999672             7.157757                   7.157757
# std                0.018122            28.628149                  28.628149
# min                0.000000             1.000000                   1.000000
# 25%                1.000000             1.000000                   1.000000
# 50%                1.000000             1.000000                   1.000000
# 75%                1.000000             3.000000                   3.000000
# max                1.000000           502.000000                 502.000000
#
#           latitude    longitude  accommodates    bathrooms     bedrooms  \
# count  3818.000000  3818.000000   3818.000000  3802.000000  3812.000000
# mean     47.628961  -122.333103      3.349398     1.259469     1.307712
# std       0.043052     0.031745      1.977599     0.590369     0.883395
# min      47.505088  -122.417219      1.000000     0.000000     0.000000
# 25%      47.609418  -122.354320      2.000000     1.000000     1.000000
# 50%      47.623601  -122.328874      3.000000     1.000000     1.000000
# 75%      47.662694  -122.310800      4.000000     1.000000     2.000000
# max      47.733358  -122.240607     16.000000     8.000000     7.000000
#
#               beds  square_feet        price  weekly_price  monthly_price  \
# count  3817.000000    97.000000  3817.000000   1534.000000     121.000000
# mean      1.735394   854.618557   127.747708    567.557366     825.677686
# std       1.139480   671.404893    89.150860    198.496058     113.002892
# min       1.000000     0.000000    20.000000    100.000000     500.000000
# 25%       1.000000   420.000000    75.000000    413.500000     750.000000
# 50%       1.000000   750.000000   100.000000    550.000000     850.000000
# 75%       2.000000  1200.000000   150.000000    700.000000     900.000000
# max      15.000000  3000.000000   999.000000    999.000000     995.000000
#
#        security_deposit  cleaning_fee  guests_included  extra_people  \
# count       1813.000000   2788.000000      3818.000000   3818.000000
# mean         254.484832     61.710904         1.672603     10.667627
# std          149.748562     48.830341         1.311040     17.585922
# min           95.000000      5.000000         0.000000      0.000000
# 25%          150.000000     25.000000         1.000000      0.000000
# 50%          200.000000     50.000000         1.000000      0.000000
# 75%          300.000000     83.000000         2.000000     20.000000
# max          995.000000    300.000000        15.000000    300.000000
#
#        minimum_nights  maximum_nights  availability_30  availability_60  \
# count     3818.000000     3818.000000      3818.000000      3818.000000
# mean         2.369303      780.447617        16.786276        36.814825
# std         16.305902     1683.589007        12.173637        23.337541
# min          1.000000        1.000000         0.000000         0.000000
# 25%          1.000000       60.000000         2.000000        13.000000
# 50%          2.000000     1125.000000        20.000000        46.000000
# 75%          2.000000     1125.000000        30.000000        59.000000
# max       1000.000000   100000.000000        30.000000        60.000000
#
#        availability_90  availability_365  number_of_reviews  \
# count      3818.000000       3818.000000        3818.000000
# mean         58.082504        244.772656          22.223415
# std          34.063845        126.772526          37.730892
# min           0.000000          0.000000           0.000000
# 25%          28.000000        124.000000           2.000000
# 50%          73.000000        308.000000           9.000000
# 75%          89.000000        360.000000          26.000000
# max          90.000000        365.000000         474.000000
#
#        review_scores_rating  review_scores_accuracy  \
# count           3171.000000             3160.000000
# mean              94.539262                9.636392
# std                6.606083                0.698031
# min               20.000000                2.000000
# 25%               93.000000                9.000000
# 50%               96.000000               10.000000
# 75%               99.000000               10.000000
# max              100.000000               10.000000
#
#        review_scores_cleanliness  review_scores_checkin  \
# count                3165.000000            3160.000000
# mean                    9.556398               9.786709
# std                     0.797274               0.595499
# min                     3.000000               2.000000
# 25%                     9.000000              10.000000
# 50%                    10.000000              10.000000
# 75%                    10.000000              10.000000
# max                    10.000000              10.000000
#
#        review_scores_communication  review_scores_location  \
# count                  3167.000000             3163.000000
# mean                      9.809599                9.608916
# std                       0.568211                0.629053
# min                       2.000000                4.000000
# 25%                      10.000000                9.000000
# 50%                      10.000000               10.000000
# 75%                      10.000000               10.000000
# max                      10.000000               10.000000
#
#        review_scores_value  calculated_host_listings_count  reviews_per_month  \
# count          3162.000000                     3818.000000        3191.000000
# mean              9.452245                        2.946307           2.078919
# std               0.750259                        5.893029           1.822348
# min               2.000000                        1.000000           0.020000
# 25%               9.000000                        1.000000           0.695000
# 50%              10.000000                        1.000000           1.540000
# 75%              10.000000                        2.000000           3.000000
# max              10.000000                       37.000000          12.150000
#
#        host_since_age  first_review_age  last_review_age
# count     3816.000000       3191.000000      3191.000000
# mean       837.273585        407.743027        74.533375
# std        569.795123        402.669792       112.619230
# min          1.000000          1.000000         1.000000
# 25%        355.000000        134.000000        15.000000
# 50%        752.500000        232.000000        40.000000
# 75%       1235.000000        553.500000        99.000000
# max       2611.000000       2402.000000      1570.000000

# %% [markdown]
# Examining the calendar DataFrame:

# %%
cal.head()
# Out:
#    listing_id       date  available  price
# 0      241032 2016-01-04       True   85.0
# 1      241032 2016-01-05       True   85.0
# 2      241032 2016-01-06      False    NaN
# 3      241032 2016-01-07      False    NaN
# 4      241032 2016-01-08      False    NaN

# %% [markdown]
# ## Question Calendar - how are prices year-long - are they going up?

# %% [markdown]
# We are going to check out how is the price varying through out the year

# %%
cal.groupby(['date']).agg({'price':'mean'}).plot()

# %%
cal.groupby(['date']).agg({'price':'mean'}).rolling(window=30).mean().plot()

# %% [markdown]
# With a rolling average of 30 days we can smooth the trend and realize that during the months of July to September the pices peak considerably, going from `$ 120` reaching more than `$150`.<br>
# Moreover,comparing the beginning of the year of 2017 and the begining of 2016 we can also see that prices gone up 12.5%

# %% [markdown]
# ## Questions Listing

# %% [markdown]
# What ate the characteristics of the Seatle airbnb market? What neighbourhoods have most listings, how are the prices in different places and what kind of property is listed? <br>
# We are now going to find out more about them:

# %% [markdown]
# We can see below the basically the Seatle market is distributed in Apartments and Houses:

# %%
listing.groupby('property_type').count().sort_values(by='id',ascending=False).id.plot.bar()

# %% [markdown]
# Entire home/apt is much more common than the other modalities (private/shared room):

# %%
listing.groupby('room_type').count().sort_values(by='id',ascending=False).id.plot.bar()

# %% [markdown]
# The neighbourhood that have most listing is Capitol Hill:

# %%
listing.groupby('neighbourhood_group_cleansed').count().sort_values(by='id',ascending=False).head(15).id.plot.bar()

# %% [markdown]
# The most expensive neighbourhhor is Magnolia:

# %%
listing.groupby('neighbourhood_group_cleansed').mean().sort_values(by='price',ascending=False).head(15).price.plot.bar()

# %% [markdown]
# But if we look at the rates per person (price divided by the number of guests included) we can see that actually downtown is a little bit more expensive

# %%
listing['price_per_person']=listing['price']/listing['guests_included']

# %%
#removing 0's in guest included 
listing[listing.guests_included>0].groupby('neighbourhood_group_cleansed'
               ).mean().sort_values(by='price_per_person',ascending=False).head(15).price_per_person.plot.bar()

# %% [markdown]
# Finally we can see where the most expensive areas are located in relation tothe other ones.
# The southside of Seatle and downtow are the most expensive areas whereas the noth side is cheaper:

# %%
price_heat_map=listing.groupby(['neighbourhood_group_cleansed']).mean().reset_index()

# %%
fig, ax = plt.subplots()
plt.scatter(price_heat_map.latitude,
            price_heat_map.longitude, 
            c=price_heat_map.price, 
            )

for i in price_heat_map.iterrows():
    ax.annotate(i[1].neighbourhood_group_cleansed,(i[1].latitude,i[1].longitude))

plt.colorbar()
plt.show()

# %% [markdown]
# By looking at the date we'll notice some columns are mere indicators of the listing id such as url, pictures_url as so on.
# Others are highly descriptive and are to cumbersome to use as comparisson such as neighborhood_overview,transit, etc
#
# We will define the columns that have well defined cetegories such as host_response_time and true/false columns

# %%
categorical_listing=['host_is_superhost',
                     'neighbourhood_group_cleansed',
                     'host_has_profile_pic',
                     'host_identity_verified',
                     'property_type',
                     'room_type',
                     'bed_type',
                     'instant_bookable',
                     'cancellation_policy',
                     'require_guest_profile_picture',
                     'require_guest_phone_verification'
                    ]

# %%
numerics = ['int32', 'int64', 'float64']

numeric_listing =list(listing.select_dtypes(include=numerics).columns)

# %%
numeric_listing=[ 'latitude',
                 'longitude',
                 'accommodates',
                 'bathrooms',
                 'bedrooms',
                 'beds',
                 'square_feet',
                 'price',
                 'guests_included',
                 'extra_people',
                 'minimum_nights',
                 'maximum_nights',
                 'review_scores_value'
]

# %% [markdown]
# By plotting the corretation heatmap we can see that the mais factors that are correlated to price are the ones related to the size of the acommodation (sq feet, bathroom, bedrooms, etc)

# %%
fig, ax = plt.subplots(figsize=(15,15))
sns.heatmap(listing[numeric_listing].corr(), annot=True, fmt=".2f")

# %% [markdown]
# Now we will make a lineal model to predict the price based on the numeric values as well as the categorical values:

# %%
def clean_data_regression(df,cat_vars):

    # Drop rows with missing price values
    df = df.dropna(subset=['price'], axis=0)
    y = df['price']
    
    X=df.drop(columns=['price'])
    
        
    # fill nan values with the mean
    num_X =X.select_dtypes(include=['int','float']).copy()
    
    for col in num_X:
        X[col].fillna((X[col].mean()), inplace=True)
        
    # Dummy the categorical variables
    
    for var in  cat_vars:
        # for each cat add dummy var, drop original column
        X = pd.concat([X.drop(var, axis=1), pd.get_dummies(X[var], prefix=var, prefix_sep='_', drop_first=True)], axis=1)
    
    return X, y
 
df_listing=listing[numeric_listing+categorical_listing].copy()  
X, y = clean_data_regression(df_listing,categorical_listing)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .20, random_state=42)

# %%
lm_model = LinearRegression(normalize=True) 

#Fit - why does this break?
lm_model.fit(X_train, y_train)
# Out:
# LinearRegression(normalize=True)

# %%
def coef_weights(coefficients, X_train):
    '''
    INPUT:
    coefficients - the coefficients of the linear model 
    X_train - the training data, so the column names can be used
    OUTPUT:
    coefs_df - a dataframe holding the coefficient, estimate, and abs(estimate)
    
    Provides a dataframe that can be used to understand the most influential coefficients
    in a linear model by providing the coefficient estimates along with the name of the 
    variable attached to the coefficient.
    '''
    coefs_df = pd.DataFrame()
    coefs_df['est_int'] = X_train.columns
    coefs_df['coefs'] = lm_model.coef_
    coefs_df['abs_coefs'] = np.abs(lm_model.coef_)
    coefs_df = coefs_df.sort_values('abs_coefs', ascending=False)
    return coefs_df

#Use the function
coef_df = coef_weights(lm_model.coef_, X_train)

# %% [markdown]
# The factors that most define priceing are the ones related to the location of the linsting:

# %%
coef_df
# Out:
#                                              est_int       coefs   abs_coefs
# 32                                property_type_Boat  177.299533  177.299533
# 0                                           latitude -125.637013  125.637013
# 1                                          longitude  -82.638697   82.638697
# 38                                property_type_Dorm  -79.261443   79.261443
# 47                             room_type_Shared room  -67.794789   67.794789
# 29                         host_has_profile_pic_True  -49.278343   49.278343
# 35                           property_type_Camper/RV   47.378978   47.378978
# 18             neighbourhood_group_cleansed_Downtown   36.533703   36.533703
# 46                            room_type_Private room  -35.963632   35.963632
# 15              neighbourhood_group_cleansed_Cascade   34.128897   34.128897
# 40                                property_type_Loft   32.811388   32.811388
# 44                           property_type_Treehouse   32.571345   32.571345
# 4                                           bedrooms   31.695268   31.695268
# 17             neighbourhood_group_cleansed_Delridge  -31.048427   31.048427
# 3                                          bathrooms   28.038026   28.038026
# 24           neighbourhood_group_cleansed_Queen Anne   25.977128   25.977128
# 14         neighbourhood_group_cleansed_Capitol Hill   25.784608   25.784608
# 25       neighbourhood_group_cleansed_Rainier Valley  -24.626564   24.626564
# 26          neighbourhood_group_cleansed_Seward Park  -24.220773   24.220773
# 33                            property_type_Bungalow   20.979758   20.979758
# 21             neighbourhood_group_cleansed_Magnolia   20.028940   20.028940
# 45                                property_type_Yurt   18.277411   18.277411
# 48                                    bed_type_Couch  -17.597270   17.597270
# 42                                property_type_Tent  -16.194414   16.194414
# 13          neighbourhood_group_cleansed_Beacon Hill  -16.045613   16.045613
# 31                     property_type_Bed & Breakfast   15.291273   15.291273
# 22            neighbourhood_group_cleansed_Northgate  -13.325074   13.325074
# 34                               property_type_Cabin    9.465846    9.465846
# 50                            bed_type_Pull-out Sofa   -9.243967    9.243967
# 37                         property_type_Condominium    9.060164    9.060164
# 28         neighbourhood_group_cleansed_West Seattle   -8.339093    8.339093
# 55                require_guest_profile_picture_True    6.886176    6.886176
# 19             neighbourhood_group_cleansed_Interbay    6.307036    6.307036
# 56             require_guest_phone_verification_True   -6.302773    6.302773
# 2                                       accommodates    6.281304    6.281304
# 53                      cancellation_policy_moderate   -5.618967    5.618967
# 52                             instant_bookable_True   -5.411412    5.411412
# 5                                               beds    5.406225    5.406225
# 12                            host_is_superhost_True    5.230341    5.230341
# 49                                    bed_type_Futon   -5.058157    5.058157
# 20            neighbourhood_group_cleansed_Lake City    4.778317    4.778317
# 39                               property_type_House    4.687044    4.687044
# 51                                 bed_type_Real Bed   -4.399928    4.399928
# 30                       host_identity_verified_True   -2.842367    2.842367
# 7                                    guests_included    2.113057    2.113057
# 23  neighbourhood_group_cleansed_Other neighborhoods    1.450594    1.450594
# 11                               review_scores_value   -1.442957    1.442957
# 43                           property_type_Townhouse    1.363849    1.363849
# 41                               property_type_Other   -1.274905    1.274905
# 36                              property_type_Chalet    1.120779    1.120779
# 54                        cancellation_policy_strict   -0.745269    0.745269
# 16         neighbourhood_group_cleansed_Central Area    0.459985    0.459985
# 27  neighbourhood_group_cleansed_University District   -0.406021    0.406021
# 8                                       extra_people    0.125945    0.125945
# 6                                        square_feet    0.026559    0.026559
# 9                                     minimum_nights    0.010556    0.010556
# 10                                    maximum_nights   -0.000385    0.000385

# %%
y_test_preds = lm_model.predict(X_test)
y_train_preds = lm_model.predict(X_train)

#append the r2 value from the test set
r2_scores_train=r2_score(y_train, y_train_preds)
r2_scores_test=r2_score(y_test, y_test_preds)

# %% [markdown]
# The model fits really well to the variables selected, maybe indicating some overfitting due the mean filling of na values:

# %%
r2_scores_train
# Out:
# 0.5957442059896575

# %%
r2_scores_test
# Out:
# 0.5611730259592755
